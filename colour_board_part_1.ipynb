# %% [markdown]
# <a href="https://colab.research.google.com/github/mohdshahbaaz059/Algoathon-22/blob/main/colour_board_part_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

def plot_checkerboard(size=8):
  board = np.indices((size, size)).sum(axis=0) % 2

  plt.figure(figsize=(6,6))
  plt.imshow(board, cmap="gray", interpolation="nearest")

  plt.xticks([])
  plt.yticks([])
  plt.title("Checkerboard pattern", fontsize=14, fontweight="bold")

  plt.show()

plot_checkerboard(8)
