# %% [markdown]
# <a href="https://colab.research.google.com/github/mohdshahbaaz059/Algoathon-22/blob/main/march_machine_2024.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib as plt
import seaborn as sns

# %%
# !unzip /content/mechine.zip
# Out:
# Archive:  /content/mechine.zip
#   inflating: map_slot.csv

# %%
df = pd.read_csv('map_slot.csv',header=0,sep=",")

# %%
df
# Out:
#       T1    T2  Slot  LP
# 0    W01   W16  R1W1   1
# 1    W02   W15  R1W2   2
# 2    W03   W14  R1W3   3
# 3    W04   W13  R1W4   4
# 4    W05   W12  R1W5   5
# ..   ...   ...   ...  ..
# 58  R3Y1  R3Y2  R4Y1  59
# 59  R3Z1  R3Z2  R4Z1  60
# 60  R4W1  R4X1  R5WX  61
# 61  R4Y1  R4Z1  R5YZ  62
# 62  R5WX  R5YZ  R6CH  63
#
# [63 rows x 4 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# df['LP'].plot(kind='hist', bins=20, title='LP')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['LP']
# ...

# %%
df.head()
# Out:
#     T1   T2  Slot  LP
# 0  W01  W16  R1W1   1
# 1  W02  W15  R1W2   2
# 2  W03  W14  R1W3   3
# 3  W04  W13  R1W4   4
# 4  W05  W12  R1W5   5

# %%
df.tail()
# Out:
#       T1    T2  Slot  LP
# 58  R3Y1  R3Y2  R4Y1  59
# 59  R3Z1  R3Z2  R4Z1  60
# 60  R4W1  R4X1  R5WX  61
# 61  R4Y1  R4Z1  R5YZ  62
# 62  R5WX  R5YZ  R6CH  63

# %%
df.describe()
# Out:
#               LP
# count  63.000000
# mean   32.000000
# std    18.330303
# min     1.000000
# 25%    16.500000
# 50%    32.000000
# 75%    47.500000
# max    63.000000

# %%
count_column = df.shape[1]

# %%
print(count_column)
# Out:
# 4

# %%
count_row = df.shape[1]

# %%
print(count_row)
# Out:
# 4

# %%
df.max()
# Out:
# T1       Z08
# T2       Z16
# Slot    R6CH
# LP        63
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 63 entries, 0 to 62
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   T1      63 non-null     object
#  1   T2      63 non-null     object
#  2   Slot    63 non-null     object
#  3   LP      63 non-null     int64
# dtypes: int64(1), object(3)
# memory usage: 2.1+ KB

# %%
df.head(3)
# Out:
#     T1   T2  Slot  LP
# 0  W01  W16  R1W1   1
# 1  W02  W15  R1W2   2
# 2  W03  W14  R1W3   3

# %%
df.plot()

# %%
df.plot(kind = 'scatter',x='T1',y='LP')
# Out:
# <Axes: xlabel='T1', ylabel='LP'>

# %%
df.plot(kind = 'scatter',x='T1',y='T2')
# Out:
# <Axes: xlabel='T1', ylabel='T2'>

# %%
df.hist()
# Out:
# array([[<Axes: title={'center': 'LP'}>]], dtype=object)

# %%
df.plot(kind = 'hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.plot.area()
# Out:
# <Axes: >

# %%
df.plot.bar()
# Out:
# <Axes: >

# %%
df.plot.bar(stacked=True)
# Out:
# <Axes: >

# %% [markdown]
# ***Box plot/****

# %%
df.plot.box()
# Out:
# <Axes: >

# %%
df.plot.kde()
# Out:
# <Axes: ylabel='Density'>

# %%
df.plot.pie(y='LP', autopct='%1.1F%%')
# Out:
# <Axes: ylabel='LP'>

# %%
df.dropna()
# Out:
#       T1    T2  Slot  LP
# 0    W01   W16  R1W1   1
# 1    W02   W15  R1W2   2
# 2    W03   W14  R1W3   3
# 3    W04   W13  R1W4   4
# 4    W05   W12  R1W5   5
# ..   ...   ...   ...  ..
# 58  R3Y1  R3Y2  R4Y1  59
# 59  R3Z1  R3Z2  R4Z1  60
# 60  R4W1  R4X1  R5WX  61
# 61  R4Y1  R4Z1  R5YZ  62
# 62  R5WX  R5YZ  R6CH  63
#
# [63 rows x 4 columns]

# %%
df.dropna(inplace=True)

# %%
df.dropna
print(df.to_string())
# Out:
#       T1    T2  Slot  LP
# 0    W01   W16  R1W1   1
# 1    W02   W15  R1W2   2
# 2    W03   W14  R1W3   3
# 3    W04   W13  R1W4   4
# 4    W05   W12  R1W5   5
# 5    W06   W11  R1W6   6
# 6    W07   W10  R1W7   7
# 7    W08   W09  R1W8   8
# 8    X01   X16  R1X1   9
# 9    X02   X15  R1X2  10
# 10   X03   X14  R1X3  11
# 11   X04   X13  R1X4  12
# 12   X05   X12  R1X5  13
# 13   X06   X11  R1X6  14
# 14   X07   X10  R1X7  15
# 15   X08   X09  R1X8  16
# 16   Y01   Y16  R1Y1  17
# 17   Y02   Y15  R1Y2  18
# 18   Y03   Y14  R1Y3  19
# 19   Y04   Y13  R1Y4  20
# 20   Y05   Y12  R1Y5  21
# 21   Y06   Y11  R1Y6  22
# 22   Y07   Y10  R1Y7  23
# 23   Y08   Y09  R1Y8  24
# 24   Z01   Z16  R1Z1  25
# 25   Z02   Z15  R1Z2  26
# 26   Z03   Z14  R1Z3  27
# 27   Z04   Z13  R1Z4  28
# 28   Z05   Z12  R1Z5  29
# 29   Z06   Z11  R1Z6  30
# 30   Z07   Z10  R1Z7  31
# 31   Z08   Z09  R1Z8  32
# 32  R1W1  R1W8  R2W1  33
# 33  R1W2  R1W7  R2W2  34
# 34  R1W3  R1W6  R2W3  35
# 35  R1W4  R1W5  R2W4  36
# ...

# %%
df.fillna(62, inplace=True)

# %%
df.fillna

# %% [markdown]
# ***Replaceing using mean(), median(),mode()***

# %%
x = df["LP"].mean()

# %%
x
# Out:
# 32.0

# %%
df.loc[7,'T1'] = 5

# %%
df.loc

# %%
df.corr

# %% [markdown]
# ***MACHINE LEARNING*** MEAN(), MEDIAN(), MODE().***

# %%
import numpy

speed = [99,88,55,44,66,33,22,11,77,54,55,62,53,64,95]

x = numpy.mean(speed)

print(x)
# Out:
# 58.53333333333333

# %%
import numpy

speed = [99,88,55,44,66,33,22,11,77,54,55,62,53,64,95]

x = numpy.median(speed)

print(x)
# Out:
# 55.0

# %%
from scipy import stats

speed = [99,88,55,44,66,33,22,11,77,54,55,62,53,64,95]

x = stats.mode(speed)

print(x)
# Out:
# ModeResult(mode=55, count=2)
